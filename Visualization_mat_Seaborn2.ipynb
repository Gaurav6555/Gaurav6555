# %%
#install and then import matplotlib
import matplotlib.pyplot as plt

# %%
#matplotlib torender plotsin the notebook
# %matplotlib inline

# %%
x = [-3,5,7]

# %%
x
# Out:
# [-3, 5, 7]

# %%
y = [10,2,5]

# %%
fig = plt.figure(figsize = (15,3))

plt.plot(x,y)
plt.xlim(0,10)
plt.ylim(-3,8)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Line Plot')
plt.subtitle('Sales Comparison', size=20, y=1.03)

# %%
#fig.savefig('example.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# #### How to chnge the polt size

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.get_size_inches(14,3)

# %%
fig

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
# More than one axes with plt.subplots, then the second item in the tuple is Numpy
fig, axs = plt.subplots(2,4)

# %% [markdown]
# ### Matpoltlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mttrain = pd.read_csv("C:/Users/Gaurav/Downloads/train.csv")

# %%
mttrain.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mttrain.shape
# Out:
# (891, 12)

# %%
mttrain.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# table
pd.crosstab(mttrain.Pclass,mttrain.Sex)
# Out:
# Sex     female  male
# Pclass
# 1           94   122
# 2           76   108
# 3          144   347

# %%
fig.get_size_inches(14,3)

# %%
# bar plot between 2 different catogories
pd.crosstab(mttrain.Pclass,mttrain.Sex).plot(kind="bar")

# %%
mttrain["Pclass"].value_counts()
mttrain.Pclass.value_counts().plot(kind="pie")

# %%
mttrain["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
import seaborn as sns
#getting boxplot of sex with respect to each category of Pclass
sns.boxplot(x="Sex",y="Pclass",data=mttrain)

# %%
sns.pairplot(mttrain.iloc[:,2:8]) #histogram of each column and
# scatter plot of each variable with respect to other columns

# %%
plt.scatter(mttrain.Pclass,mttrain.Fare) ##scatter plot of two variable

# %%
#Graphical representation of data
#import matplotlib.pyplot as plt
#Histogram
plt.hist(mttrain['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %%
#Boxplot
#help(plt.boxplot)
plt.boxplot(mttrain['Pclass'],vert = True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29a2e8c27f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29a2e8c2eb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29a2e8c2490>],
#  'medians': [<matplotlib.lines.Line2D at 0x29a2e8ce5b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29a2e8ce8b0>],
#  'means': []}

# %%
plt.boxplot(mttrain['Pclass'],vert = False);plt.ylabel("Pclass");xlabel("Boxplot");plt.title(Boxplot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-fc78af985999> in <module>
# ----> 1 plt.boxplot(mttrain['Pclass'],vert = False);plt.ylabel("Pclass");xlabel("Boxplot");plt.title(Boxplot)
#
# NameError: name 'xlabel' is not defined

# %%
#Violin plot
#help(plt.violinplot)
plt.violinplot(mttrain["Pclass"])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x29a2e97e340>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x29a2e97e190>,
#  'cmins': <matplotlib.collections.LineCollection at 0x29a2e97e1c0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x29a2e97e790>}

# %% [markdown]
# ##### Visualizing Data with pandas

# %% [markdown]
# ## Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Gaurav/Downloads/train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.set_style("darkgrid",{'axes.grid' : True})
sns.lmplot(x= 'PassengerId',y='Age',data=df)
plt.show()

# %%
sns.lmplot(x= 'PassengerId',y='Age',data=df, hue="Sex", palette='Set1')
plt.show()

# %%
sns.lmplot(x= 'PassengerId',y='Age',data=df, col="Sex")
plt.show()

# %% [markdown]
# ### Univariate - "one variable" data visualization

# %%
#strip plot

sns.stripplot(y= 'Age', data=df, jitter=True)
plt.ylabel('Age ($)')
plt.show()

# %%
#Grouping with stripplot()
sns.stripplot(x= 'Pclass', y='PassengerId', data=df,)
plt.ylabel('Pclass ($)')
plt.show()

# %%
sns.stripplot(x= 'Pclass', y='PassengerId', data=df,size=4,jitter=False)
plt.ylabel('Pclass ($)')
plt.show()

# %%
#Swarm plot
sns.swarmplot(x= 'Pclass', y='PassengerId', data=df)
plt.ylabel('Pclass ($)')
plt.show()

# %%
sns.swarmplot(x= 'Pclass', y='PassengerId', data=df,hue='Sex',)
plt.xlabel('Pclass ($)')
plt.show()

# %%
#Changing orientation
sns.swarmplot(x= 'Pclass', y='PassengerId', data=df,hue='Sex',orient='h')
plt.xlabel('Pclass ($)')
plt.show()

# %% [markdown]
# #### Box & Violin plot

# %%
#plot.subplot(1,2,1)
sns.boxplot(x='Pclass',y='PessangerId',data=df)
plt.ylabel('PassengerId($)')

# %%
#plot.subplot(1,2,2)
sns.boxplot(x='Pclass',y='PessangerId',data=df)
plt.ylabel('PassengerId($)')
plt.show()

# %%
plot.subplot(1,2,1)
sns.boxplot(x='Pclass',y='PessangerId',data=df)
plt.ylabel('PassengerId($)')
plot.subplot(1,2,2)
sns.boxplot(x='Pclass',y='PessangerId',data=df)
plt.ylabel('PassengerId($)')

plt.show()

# %%
#combining plots
sns.violoinplot(x='Pclass',y='PessangerId',data=df, inner=None,color='lightgray')
sns.stripplot(x= 'Pclass', y='PassengerId', data=df,size=4,jitter=False)
plt.ylabel('PassengerId($)')
plt.show()

# %% [markdown]
# #### Bivariate - 'two variables' data visualization

# %%
#Join plot

sns.jointplot(x='Pclass',y='PessangerId',data=df)
plt.show()

# %%
#Density plot
sns.jointplot(x='Pclass',y='PessangerId',data=df,kind='kde')
plt.show()

# %%
#Pair plot
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue='Sex')
plt.show()

# %%
df.corr()

# %%
#Covariance heat map of df data
sns.heatmap(df.corr(),vmin=-1,vmax=1, cmap='ocean')

# %% [markdown]
# ### Titanic data visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Loading dataset

# %%
df = pd.read_csv("C:/Users/Gaurav/Downloads/train.csv")
df.head()

# %% [markdown]
# ### Data types

# %%
print(data.dtypes)

# %% [markdown]
# ### Proportion of target(Survived)

# %%
data.groupby('Survived')['PassengerId'].count()

# %% [markdown]
# ### Visual Exploration

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxpolt(x='Survived', y='Age', data=data);

# %%
f, ax = plt.subplots(figsize=(7,3))
sns.boxpolt(x='Sex', y='Survived', data=data);

# %%
f, ax = plt.subplots(figsize=(11,5))
sns.boxpolt(x='Sex', y='Age', hue="Survived" data=data);

# %%
sns.barplot(x="Pclass", y="Survived", data=data);

# %%
sns.barplot(x="Pclass", y="Survived", hue="Sex", data=data);

# %%
sns.barplot(x="SibSp", y="Survived", data=data);

# %%
sns.barplot(x="Parch", y="Survived", data=data);

# %%
#data["family"] =data["SibSp"] + data["Parch"]
#data["occumpanied"] = data["family"].apply(lambda x: o if x == 0 else 1)
#sns.barplot(x="Survied", y="occumpanied", data=data);

# %% [markdown]
# #### Those who are occumpanied by a family member(elder or siblings)  had high survival rate

# %% [markdown]
# #### Passengers aged between 18-38 had high survival rate compared to others

# %%
survived = data.loc[data['Survived']==1,"Age"].dropna()
sns.distplot(survived)
plt.title("Survived");

# %%
not_survived = data.loc[data['Survived']==0,"Age"].dropna()
sns.distplot(not_survived)
plt.title("Not_Survived");

# %% [markdown]
# #### Infants had high survival rate and elderly passengers above 65+were less likely to survive

# %%
sns.pairplot(data.dropna());

# %%
# Pclass vs Survive
grid = sns.Facegrid(data, col='Survived', row='Pclass', size=2.4, aspect=1.5)
grid.map(plt.hist, 'Age', alpha=.5, bins=20)
grid.add_legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b342e87543cf> in <module>
#       1 # Pclass vs Survive
# ----> 2 grid = sns.Facegrid(data, col='Survived', row='Pclass', size=2.4, aspect=1.5)
#       3 grid.map(plt.hist, 'Age', alpha=5, bins=20)
#       4 grid.add_legend()
#
# AttributeError: module 'seaborn' has no attribute 'Facegrid'

# %%
# grid = sns.Facegrid(train_df, col='Embarked', hue='Survived', pallete={0: 'k',1})
grid = sns.Facegrid(data, col='Survived', row='Embarked', size=2.2, aspect=1.6)
grid.map(sns.barplot, 'Sex','Fare', alpha=.5, ci=None)
grid.add_legend()

# %%
data.columns

# %%
grid = sns.Facegrid(data, col='Sex', row='Pclass')
grid.map(plt.hist, 'Age', alpha=.5, bins=40)
grid.add_legend()

# %%
sns.distplot(a=data[data['Embarked']=='C']['Survived'],bins=3,kde=False)
plt.title("Cherbourg")
plt.xticks([0,1])
plt.show()
plt.title("QueensTown")
sns.distplot(a=data[data['Embarked']=='Q']['Survived'],bins=3,kde=False)
plt.xticks([0,1])

plt.show()
#Most of the passengers embarked from Southampton

# %%
figbi, axesbi = plt.subplots(2,4, figsize=(16,10))
data.groupby('Pclass')['Survived'].mean().plot(kind='barch',ax=axesbi[0,0],xlim[0,1])
data.groupby('SibSp')['Survived'].mean().plot(kind='barch',ax=axesbi[0,1],xlim[0,1])
data.groupby('Parch')['Survived'].mean().plot(kind='barch',ax=axesbi[0,2],xlim[0,1])
data.groupby('Sex')['Survived'].mean().plot(kind='barch',ax=axesbi[0,3],xlim[0,1])
data.groupby('Embarked')['Survived'].mean().plot(kind='barch',ax=axesbi[1,0],xlim[0,1])
sns.boxplot(x="Survived", y="Age", data=data,ax=axesbi[1,1])
sns.boxplot(x="Survived", y="Fare", data=data,ax=axesbi[1,2])
